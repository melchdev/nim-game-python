# %% [markdown]
# # PythoNim - rebuild

# %% [markdown]
# Originally developed by David Sebastián Mendoza Cruz and Juan Sebastián Díaz Mora
# for the course *Introduction to Computer Science and Programming* at Universidad Nacional de Colombia (UNAL).

# %% [markdown]
# ---

# %% [markdown]
# ## Objective
#
# The goal of this notebook is to reconstruct the Nim game from scratch without referencing the original implementation.
#
# This process focuses on:
# - Reinforcing understanding of core game logic
# - Structuring code in a clear and modular way
# - Practicing clean coding principles
# - Preparing the codebase for future refactoring into a CLI application

# %% [markdown]
# ## Game Rules
#
# - The game consists of several piles of objects
# - Two players take turns
# - On each turn, a player removes one or more objects from a single pile
# - A player must remove at least one object
# - The player who removes the last object wins

# %% [markdown]
# ## Game Design Decisions
#
# - The game will be implemented as a human vs human game in its initial version
# - The initial state of the game will be defined by a fixed list of piles
# - The game will run in a command-line style interaction using input/output

# %% [markdown]
# ## Game Flow
#
# The game loop will follow these steps:
#
# 1. Initialize the game state (piles)
# 2. Set the starting player
# 3. Display the current state of the game
# 4. Ask the current player for a move
# 5. Validate the move
# 6. Apply the move to the game state
# 7. Check if the game has ended
# 8. If the game is not over, switch player and repeat

# %% [markdown]
# ## Implementation

# %%
running = True

def game():
    print("Let's play!")
    print("Setting the board...")

    playing = True
    pile = {"A": 3, "B": 4, "C": 5}
    for key, value in pile.items():
        print(f"Pile {key}: ", end='') 
        for i in range(value):
            print("O", end= ' ')
        print("")

    print("Soon you will be playing PythoNIM")


def how_to_play():
    print("\nHow to Play PythoNim\n")
    
    print("PythoNim is a recreation of the classic Nim game.")
    print("It is played by two players using three piles: A, B, and C.\n")
    
    print("Initial setup:")
    print("Pile A: 3 items")
    print("Pile B: 4 items")
    print("Pile C: 5 items\n")
    
    print("Rules:")
    print("- Players take turns.")
    print("- On each turn, a player selects one pile.")
    print("- The player can remove any number of items from that pile (at least one).")
    print("- The player who removes the last item wins.\n")

def more_info():
    print("Game made by David Mendoza and Juan Díaz.")
    return False

while running:
    print("Welcome to PythoNIM!")
    print("Choose an option: ")
    
    option = int(input("1. Play the game \n 2. How to Play \n 3. More Info \n 4. Exit"))
    match option:
        case 1:
            game()
        case 2:
            how_to_play()
        case 3:
            more_info()
        case 4:
            print("Thanks for playing! Click the execute button to play again")
            break
